# %%
import numpy as np 
import matplotlib.pyplot as plt

f0_45 = open("interacting_metropolis_local_energy_values_a_0.000000num_particles_10num_dims_3alpha_0.450000.txt", "r")
f0_50 = open("interacting_metropolis_local_energy_values_a_0.000000num_particles_10num_dims_3alpha_0.500000.txt", "r")
f0_55 = open("interacting_metropolis_local_energy_values_a_0.000000num_particles_10num_dims_3alpha_0.550000.txt", "r")

local_energies_0_45 = np.array([float(j) for j in np.array([i for i in f0_45])[:-1]])
local_energies_0_50 = np.array([float(j) for j in np.array([i for i in f0_50])[:-1]])
local_energies_0_55 = np.array([float(j) for j in np.array([i for i in f0_55])[:-1]])

alpha_vals = [0.45, 0.50, 0.55]

means = np.array([np.mean(l) for l in [local_energies_0_45, local_energies_0_50,local_energies_0_55]])
stds = np.array([np.std(l) for l in [local_energies_0_45, local_energies_0_50,local_energies_0_55]])


plt.xlabel("alpha")

plt.scatter(alpha_vals, means)
plt.show()
plt.scatter(alpha_vals, means/10.)

print("Energy per particle: ", means/1.)
print("SD                 : ", stds)
# Out:
# Energy per particle:  [24.27462216 24.14       24.24919301]
# SD                 :  [7.50892037e-01 2.48689958e-14 6.73980295e-01]

# %%
import numpy as np 
import matplotlib.pyplot as plt

f0_45 = open("interacting_metropolis_local_energy_values_a_0.000000num_particles_50num_dims_3alpha_0.450000.txt", "r")
f0_50 = open("interacting_metropolis_local_energy_values_a_0.000000num_particles_50num_dims_3alpha_0.500000.txt", "r")
f0_55 = open("interacting_metropolis_local_energy_values_a_0.000000num_particles_50num_dims_3alpha_0.550000.txt", "r")

local_energies_0_45 = np.array([float(j) for j in np.array([i for i in f0_45])[:-1]])
local_energies_0_50 = np.array([float(j) for j in np.array([i for i in f0_50])[:-1]])
local_energies_0_55 = np.array([float(j) for j in np.array([i for i in f0_55])[:-1]])

alpha_vals = [0.45, 0.50, 0.55]

means = np.array([np.mean(l) for l in [local_energies_0_45, local_energies_0_50,local_energies_0_55]])
stds = np.array([np.std(l) for l in [local_energies_0_45, local_energies_0_50,local_energies_0_55]])


plt.xlabel("alpha")

plt.scatter(alpha_vals, means)
plt.show()
plt.scatter(alpha_vals, means/50.)

print("Energy per particle: ", means/1.)
print("SD                 : ", stds)
# Out:
# Energy per particle:  [121.48634465 120.7        121.16150127]
# SD                 :  [1.72334878e+00 1.27897692e-13 1.76284075e+00]
