# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib qt
from plotting_tools import plot_energy

from plotting_tools import create_table_non_interacting, create_table_interacting

create_table_interacting("bf", "output/interacting_true/",2, 2, 1000000)

plot_energy("bf", "output/interacting_true/",2, 2, 1000000)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# \begin{table}
# \centering
# \caption{Optimal energy, error and time for different network architectures using Metropolis Brute-force on a interacting system with 2 particles in 2 dimensions. Using $\sigma^2 = $1.0, MC-iterations = 1000000 and MC step-length = 0.5}
# \begin{tabular}{lrrrr}
# \toprule
#          Network Architecture &  Optimal Energy &  Abs error &  Rel error &  Time [s] \\
# \midrule
#  lr = 0.01 , hidden nodes = 2 &          3.2354 &     1.2354 &    0.61770 &   574.306 \\
#  lr = 0.01 , hidden nodes = 3 &          3.1987 &     1.1987 &    0.59935 &   640.024 \\
#  lr = 0.01 , hidden nodes = 4 &          3.1686 &     1.1686 &    0.58430 &   681.869 \\
#   lr = 0.1 , hidden nodes = 2 &          3.1468 &     1.1468 &    0.57340 &   583.606 \\
#   lr = 0.1 , hidden nodes = 3 &          3.0851 &     1.0851 &    0.54255 &   639.169 \\
#   lr = 0.1 , hidden nodes = 4 &          3.0860 &     1.0860 &    0.54300 &   702.625 \\
#   lr = 1.0 , hidden nodes = 2 &          3.1172 &     1.1172 &    0.55860 &   588.109 \\
#   lr = 1.0 , hidden nodes = 3 &          3.0830 &     1.0830 &    0.54150 &   653.079 \\
#   lr = 1.0 , hidden nodes = 4 &          3.0840 &     1.0840 &    0.54200 &   715.149 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# interacting_true
